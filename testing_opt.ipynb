# %%
# %pylab inline


import numpy as np

import numba as nb

import matplotlib.pyplot as plt

import gibbs
from gibbs import BiddleFreeEn

import dirty_root
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
N = 1000
Ts = np.linspace(200,300,N)

Ps = np.linspace(1,300,N)

# %%
bid = BiddleFreeEn()

# %%
That = bid.convert_T(Ts)
Phat = bid.convert_P(Ps)

# %%
mixer = bid.mixer

# %%
# x = bid.x(Ts,Ps)

## took 9.54 minutes with opt.minimize

# %%
# func = nb.jit(mixer.energy_x_grad)

# %%
dirty_root.fast_opt(mixer,That,Phat)
# Out:
# /home/aidan/my_gits/ts_eos/dirty_root.py:70: NumbaWarning:
# Compilation is falling back to object mode WITHOUT looplifting enabled because Function "opt_one" failed type inference due to: Failed in nopython mode pipeline (step: nopython frontend)
# Unknown attribute 'brentq' of type Module(<module 'scipy.optimize' from '/home/aidan/anaconda3/lib/python3.8/site-packages/scipy/optimize/__init__.py'>)
#
# File "dirty_root.py", line 57:
# def brent_jit(func,T:np.float64,P:np.float64,lower = 0,upper = 1):
#     <source elided>
#
#     return opt.brentq(func,lower,upper,args = (T,P))
#     ^
#
# During: typing of get attribute at /home/aidan/my_gits/ts_eos/dirty_root.py (57)
#
# File "dirty_root.py", line 57:
# def brent_jit(func,T:np.float64,P:np.float64,lower = 0,upper = 1):
#     <source elided>
#
#     return opt.brentq(func,lower,upper,args = (T,P))
#     ^
#
# During: resolving callee type: type(CPUDispatcher(<function brent_jit at 0x7fa221052700>))
# ...
